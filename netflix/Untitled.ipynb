# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\archanaseelan\Desktop\Datascienceprojects\DataAnalysis_projects\netflix\netflix_titles.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.size
# Out:
# 105684

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
#task1 is there any duplicate record in this dataset? if yes, then remove the duplicate records  duplicate()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.drop_duplicates()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.drop_duplicates(inplace=True)       # to remove duplicate rows permanently

# %%
# Task2 Is there any Null Value present in any column? Show with Heat-map.

# %%
# isnull()

# %%
#to show where the null value is present
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# To show the count of Null values in each column
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#seaborn library (heat-map)
import seaborn as sns  # importing seaborn library

# %%
#Using heat-map to show null values count
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#Q1. For 'House of cards'., What is the show id and Who is the Director of this show?  isin()  and str.contraints()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# To show all records of a particular item in any column
data['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
data['title'].isin(['House of Cards'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
data[data['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
# To show all records of a particular string in my column
data['title'].str.contains('House of Cards')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: title, Length: 8807, dtype: bool

# %%
data[data['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
#Q2. In which year highest number of the TV Shows & Movies were released? Show with Bar Graph  dtpes

# %%
#dtypes
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#to_datatime
data['Date_N'] = pd.to_datetime(data['release_year'])

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
# dt.year.value_counts()  it counts the occurrence of all individual years in Date column.
data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 1970    8807
# Name: count, dtype: int64

# %%
#Bar graph
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %%
#Q3. How many Movies & TV Shows are in the dataset? Show with Bar Graph

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# To group all unique items of a column and show their count  data.groupby()
data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
# To show the count of all unique values of any column in the form of bar graph
#countplot()

sns.countplot(data['type'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 4
#       1 # To show the count of all unique values of any column in the form of bar graph
#       2 #countplot()
# ----> 4 sns.countplot(data['type'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
#Q4 Show all the Movies that were released in year 2000
#vreatinh new column
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N
# 0 1970-01-01 00:00:00.000002020
# ...

# %%
data['Year'] = data['Date_N'].dt.year   # to create new year column; it will consider only year

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N  Year
# 0 1970-01-01 00:00:00.000002020  1970
# ...

# %%
# Filtering
data[(data['type'] == 'Movie') & (data['release_year']==2018)]
# Out:
#      show_id   type                                              title  \
# 73       s74  Movie                                       King of Boys
# 94       s95  Movie                                          Show Dogs
# 96       s97  Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 107     s108  Movie                                   A Champion Heart
# 157     s158  Movie                                           Level 16
# ...      ...    ...                                                ...
# 8706   s8707  Movie                                     We the Animals
# 8724   s8725  Movie                                 What Still Remains
# 8732   s8733  Movie                                      White Chamber
# 8743   s8744  Movie                                           Wildlife
# 8774   s8775  Movie                                          يوم الدين
#
#                 director                                               cast  \
# ...

# %%
#Q5 Show only the titles of all TV Shows that were released in india only

# %%
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[(data['type']=='TV Show') & (data['country']=='India')]
# Out:
#      show_id     type                               title director  \
# 4         s5  TV Show                        Kota Factory      NaN
# 39       s40  TV Show                        Chhota Bheem      NaN
# 50       s51  TV Show                       Dharmakshetra      NaN
# 66       s67  TV Show       Raja Rasoi Aur Anya Kahaniyan      NaN
# 69       s70  TV Show      Stories by Rabindranath Tagore      NaN
# ...      ...      ...                                 ...      ...
# 8173   s8174  TV Show                           Thackeray      NaN
# 8235   s8236  TV Show                         The Calling    Bumpy
# 8321   s8322  TV Show  The Golden Years with Javed Akhtar      NaN
# 8349   s8350  TV Show              The House That Made Me      NaN
# 8775   s8776  TV Show                     Yeh Meri Family      NaN
#
#                                                    cast country  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# ...

# %%
data[(data['type']=='TV Show') & (data['country']=='India')]['title']
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
#Q6. Show top 10 directors, who gave the highest number of TV Shows & Movies to Netflix?
# value_counts
data['director'].value_counts()
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %%
data['director'].value_counts().head()
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Name: count, dtype: int64

# %%
#q4. Show all the Records, where 'Category' is movie and type is 'comedies' or Country in united kingdom
data[(data['type']=='Movie') & (data['listed_in']=='Comedies')]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
data[(data['type']=='Movie') & (data['listed_in']=='Comedies') | (data['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
# Q8  In how many movie/shows, Tom Cruise was cast?
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N  Year
# 0 1970-01-01 00:00:00.000002020  1970
# ...

# %%
data['cast'] == 'Tom Cruise'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: cast, Length: 8807, dtype: bool

# %%
data[data['cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, Year]
# Index: []

# %%
# str.contains()
data[data['cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 2
#       1 # str.contains()
# ----> 2 data[data['cast'].str.contains('Tom Cruise')]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3883, in DataFrame.__getitem__(self, key)
#    3880     return self.where(key)
#    3882 # Do we have a (boolean) 1d indexer?
# -> 3883 if com.is_bool_indexer(key):
#    3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     130     if lib.is_bool_array(key_array, skipna=True):
# ...

# %%
#Creating new data-frame by removing the null values
data_new =data.dropna()

# %%
data_new.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description  \
# ...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added  release_year rating duration  \
# 341   August 1, 2021          1999      R  189 min
# 1254   March 1, 2021          1988      R  134 min
#
#                        listed_in  \
# 341   Dramas, Independent Movies
# 1254      Classic Movies, Dramas
#
#                                             description  \
# 341   Through chance, history and divine interventio...
# 1254  Motivated by money, a selfish workaholic seeki...
#
#                             Date_N  Year
# 341  1970-01-01 00:00:00.000001999  1970
# 1254 1970-01-01 00:00:00.000001988  1970

# %%
#Q9. What are the different Ratings defined by netflix?
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N  Year
# 0 1970-01-01 00:00:00.000002020  1970
# ...

# %%
data['rating'].nunique()
# Out:
# 17

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
# Q 9.1 How many Movies got the 'TV-14' rating in Canada?
data.head(100)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# ..     ...      ...                                                ...
# 95     s96  TV Show                                         The Circle
# 96     s97    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 97     s98  TV Show                                         Kid Cosmic
# 98     s99  TV Show                          Octonauts: Above & Beyond
# 99    s100  TV Show                                       On the Verge
#
#            director                                               cast  \
# ...

# %%
data[(data['type']=='Movie') & (data['rating'] == 'TV-14')]
# Out:
#      show_id   type                                              title  \
# 18       s19  Movie                                          Intrusion
# 24       s25  Movie                                              Jeans
# 30       s31  Movie                                    Ankahi Kahaniya
# 51       s52  Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53  Movie  InuYasha the Movie 3: Swords of an Honorable R...
# ...      ...    ...                                                ...
# 8772   s8773  Movie                              Yamla Pagla Deewana 2
# 8774   s8775  Movie                                          يوم الدين
# 8794   s8795  Movie                                             اشتباك
# 8799   s8800  Movie                                              Zenda
# 8806   s8807  Movie                                             Zubaan
#
#                                                director  \
# 18                                           Adam Salky
# ...

# %%
data[(data['type']=='Movie') & (data['rating'] == 'TV-14')].shape
# Out:
# (1427, 14)

# %%
data[(data['type']=='Movie') & (data['rating'] == 'TV-14') & (data['country'] == 'Canada')].shape
# Out:
# (13, 14)

# %%
#Q 9.2 How many TV show got the 'R' rating after year 2018?
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N  Year
# 0 1970-01-01 00:00:00.000002020  1970
# ...

# %%
data[(data['type'] == 'TV Show') & (data['rating']=='R')]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added  release_year rating  duration  \
# 3893     April 25, 2019          2015      R  1 Season
# 7593  December 10, 2016          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description  \
# 3893  Trapped at a stagecoach stop as a storm rages ...
# 7593  A series of incidents in Afghanistan set compl...
#
# ...

# %%
data[(data['type'] == 'TV Show') & (data['rating']=='R') & (data['release_year'] > 2018)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, Year]
# Index: []

# %%
# Q10 What is the maximum duration of the Movie/Show on netflix?

data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N  Year
# 0 1970-01-01 00:00:00.000002020  1970
# ...

# %%
data.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
data.duration.dtypes
# Out:
# dtype('O')

# %%
#str.split()
data[['Minutes', 'Unit']] = data['duration'].str.split(' ', expand = True)

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N  Year Minutes     Unit
# ...

# %%
data['Minutes'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 data['Minutes'].mean()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# ...

# %%
# Q 11 Which individual country has the Highest no. of Tv Shows

# %%
data_tvshow = data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  \
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
#
#                          Date_N  Year Minutes     Unit
# ...

# %%
data_tvshow.country.value_counts()
# Out:
# country
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: count, Length: 196, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# country
# United States    760
# Name: count, dtype: int64

# %%
# Q12 How can we sort the dataset by Year?
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  \
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
#
#                          Date_N  Year Minutes     Unit
# ...

# %%
data.sort_values(by='release_year').head(2)
# Out:
#      show_id     type                              title     director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*          NaN  NaN
# 7790   s7791    Movie                     Prelude to War  Frank Capra  NaN
#
#             country         date_added  release_year rating  duration  \
# 4250            NaN  December 30, 2018          1925  TV-14  1 Season
# 7790  United States     March 31, 2017          1942  TV-14    52 min
#
#                           listed_in  \
# 4250                       TV Shows
# 7790  Classic Movies, Documentaries
#
#                                             description  \
# 4250  This collection restores films from women who ...
# 7790  Frank Capra's documentary chronicles the rise ...
#
#                             Date_N  Year Minutes    Unit
# 4250 1970-01-01 00:00:00.000001925  1970       1  Season
# 7790 1970-01-01 00:00:00.000001942  1970      52     min

# %%
data.sort_values(by='release_year', ascending=False).head(2)
# Out:
#     show_id   type                                  title        director  \
# 693    s694  Movie                 Ali & Ratu Ratu Queens  Lucky Kuswandi
# 781    s782  Movie  Black Holes | The Edge of All We Know   Peter Galison
#
#                                                   cast country     date_added  \
# 693  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...     NaN  June 17, 2021
# 781                                                NaN     NaN   June 2, 2021
#
#      release_year rating duration                               listed_in  \
# 693          2021  TV-14  101 min  Comedies, Dramas, International Movies
# 781          2021  TV-14   99 min                           Documentaries
#
#                                            description  \
# 693  After his father's passing, a teenager sets ou...
# 781  Follow scientists on their quest to understand...
#
#                            Date_N  Year Minutes Unit
# 693 1970-01-01 00:00:00.000002021  1970     101  min
# ...

# %%
# Q 13. find all  the instances where:
# category is movie and type is 'dramas'
#                   or
# category is 'Tv Show and type is kids tv

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data[(data['type'] == 'Movie') & (data['listed_in'] == 'Dramas')].head(1)
# Out:
#     show_id   type  title        director  \
# 112    s113  Movie  Worth  Sara Colangelo
#
#                                                   cast country  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...     NaN
#
#             date_added  release_year rating duration listed_in  \
# 112  September 3, 2021          2021  PG-13  119 min    Dramas
#
#                                            description  \
# 112  In the wake of the Sept. 11 attacks, a lawyer ...
#
#                            Date_N  Year Minutes Unit
# 112 1970-01-01 00:00:00.000002021  1970     119  min

# %%
data[(data['type'] == 'TV Show') & (data['listed_in'] == "Kids' TV")].head(1)
# Out:
#    show_id     type                    title director  \
# 34     s35  TV Show  Tayo and Little Wizards      NaN
#
#                                                  cast country  \
# 34  Dami Lee, Jason Lee, Bommie Catherine Han, Jen...     NaN
#
#             date_added  release_year rating  duration listed_in  \
# 34  September 17, 2021          2020  TV-Y7  1 Season  Kids' TV
#
#                                           description  \
# 34  Tayo speeds into an adventure when his friends...
#
#                           Date_N  Year Minutes    Unit
# 34 1970-01-01 00:00:00.000002020  1970       1  Season

# %%
data[(data['type'] == 'Movie') & (data['listed_in'] == 'Dramas') | (data['type'] == 'Movie') & (data['listed_in'] == "Kids' TV")].head(1)
# Out:
#     show_id   type  title        director  \
# 112    s113  Movie  Worth  Sara Colangelo
#
#                                                   cast country  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...     NaN
#
#             date_added  release_year rating duration listed_in  \
# 112  September 3, 2021          2021  PG-13  119 min    Dramas
#
#                                            description  \
# 112  In the wake of the Sept. 11 attacks, a lawyer ...
#
#                            Date_N  Year Minutes Unit
# 112 1970-01-01 00:00:00.000002021  1970     119  min
